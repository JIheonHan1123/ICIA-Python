# %%
import my_utils as mu

# %%
mu.db_open()

# %%
query = 'create table test_oracle(id number(1), name varchar(5))'

# %%
mu.sql_excute(query)
# Out:
# oracle 쿼리 성공

# %%
query2 = 'select * from test_oracle'

# %%
mu.sql_excute(query2)
# Out:
# C:\Users\user\게임아이 수업자료\my_utils.py:34: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql=query, con=db)
#    ID   NAME
# 0   1  test2

# %%
query3 = "insert into test_oracle values(1, 'test2')"

# %%
mu.sql_excute(query3)
# Out:
# oracle 쿼리 성공

# %%
url = 'http://openapi.seoul.go.kr:8088/(인증키)/xml/tbLnOpendataRentV/1/1000/'

# %%
df = mu.df_creater(url)

# %%
sel_c = ['SGG_NM','BJDONG_NM','LAND_GBN_NM','FLR_NO','CNTRCT_DE','RENT_GBN','RENT_AREA','RENT_GTN','RENT_FEE','BLDG_NM','BUILD_YEAR']

# %%
my_df = df[sel_c].copy()

# %%
my_df.columns=['자치구명','법정동명','지번구분명','층수','계약일','전월세','면적','보증금','임대료','건물명','건축년도']

# %%
my_df = my_df.astype({'층수':'float', '계약일':'int','면적':'float', '보증금':'int', '임대료':'int'})

# %%
query = 'create table housePrice2(자치구명 varchar(50), 법정동명 varchar(50), 지번구분명 varchar(50), 층수 float, 계약일 number(20), 전월세 varchar(20), 면적 float, 보증금 number(20), 임대료 number(20), 건물명 varchar(100), 건축년도 varchar(20))'

# %%
mu.db_open()

# %%
mu.sql_excute(query)
# Out:
# oracle 쿼리 성공

# %%
query2 = 'select * from housePrice2'

# %%
mu.sql_excute(query2)
# Out:
# Empty DataFrame
# Columns: [자치구명, 법정동명, 지번구분명, 층수, 계약일, 전월세, 면적, 보증금, 임대료, 건물명, 건축년도]
# Index: []

# %%
my_df.건물명.iloc[0]
# Out:
# '명진주택C'

# %%
query4 = (
    f'insert into housePrice2'
    f' values({repr(my_df.자치구명.iloc[0])},'
    f'{repr(my_df.법정동명.iloc[0])}, {repr(my_df.지번구분명.iloc[0])}, {my_df.층수.iloc[0]}, {my_df.계약일.iloc[0]},'
    f'{repr(my_df.전월세.iloc[0])}, {my_df.면적.iloc[0]}, {my_df.보증금.iloc[0]}, {my_df.임대료.iloc[0]},' 
    f'{repr(my_df.건물명.iloc[0])}, {repr(my_df.건축년도.iloc[0])})' 
)
#repr은 ''로 감싸서 나오게 하는거

# %%
query4
# Out:
# "insert into housePrice2 values('강북구','수유동', '대지', 3.0, 20240412,'전세', 50.15, 27000, 0,'명진주택C', '2022')"

# %%
mu.db_open()
mu.sql_excute(query4)
mu.db_close()
# Out:
# oracle 쿼리 성공
# 오라클 정상적으로 닫힘

# %%
query6 = 'select * from housePrice2'
mu.db_open()
mu.sql_excute(query6)
# Out:
# C:\Users\user\게임아이 수업자료\my_utils.py:34: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql=query, con=db)
#   자치구명 법정동명 지번구분명   층수       계약일 전월세     면적    보증금  임대료    건물명  건축년도
# 0  강북구  수유동    대지  3.0  20240412  전세  50.15  27000    0  명진주택C  2022

# %%
len(my_df)
# Out:
# 1000

# %%
from tqdm import tqdm
from my_utils import db_open, sql_excute, db_close, seoul_api_key
# from my_utils import *

# %%
mu.db_open()
for i in tqdm(range(len(my_df))):
    query4 = (
    f'insert into housePrice2'
    f' values({repr(my_df.자치구명.iloc[i])},'
    f'{repr(my_df.법정동명.iloc[i])}, {repr(my_df.지번구분명.iloc[i])}, {my_df.층수.iloc[i]}, {my_df.계약일.iloc[i]},'
    f'{repr(my_df.전월세.iloc[i])}, {my_df.면적.iloc[i]}, {my_df.보증금.iloc[i]}, {my_df.임대료.iloc[i]},' 
    f'{repr(my_df.건물명.iloc[i])}, {repr(my_df.건축년도.iloc[i])})' 
    )
    mu.sql_excute(query4)
mu.db_close()
# Out:
#  16%|█▋        | 163/1000 [00:00<00:01, 809.53it/s]
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# oracle 쿼리 성공
# ...

# %%
query6 = 'select * from housePrice2'
mu.db_open()
mu.sql_excute(query6)
# Out:
# C:\Users\user\게임아이 수업자료\my_utils.py:34: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql=query, con=db)
#       자치구명 법정동명 지번구분명    층수       계약일 전월세     면적    보증금  임대료           건물명  \
# 0      중랑구  상봉동    대지   7.0  20240412  월세  31.65   7600   58       역세권청년주택
# 1      마포구  서교동    대지  13.0  20240412  월세  37.17  13760   70    서교동효성해링턴타워
# 2      금천구  독산동  None   0.0  20240412  전세  20.00   2700    0          None
# 3      성북구  장위동    대지   2.0  20240412  전세  59.99  52080    0    래미안장위퍼스트하이
# 4     서대문구  홍제동    대지   7.0  20240412  전세  84.90  55000    0  홍제원현대(459-0)
# ...    ...  ...   ...   ...       ...  ..    ...    ...  ...           ...
# 996    강동구  성내동    대지   5.0  20240410  월세  44.26  18000    6      산성빌리지(A)
# 997    광진구   능동  None   0.0  20240410  전세  27.00  11000    0          None
# ...

# %%
import requests

# %%
api_key = 'RGAPI-96f2dd58-1f36-4e86-a50a-cb61514088fd'

# %%
url = f'https://asia.api.riotgames.com/riot/account/v1/accounts/by-riot-id/%ED%83%80%20%EC%9E%94/KR1?api_key={api_key}'

# %%
res = requests.get(url).json()

# %%
res #json형태면서 파이썬에서는 딕셔너리형태
# Out:
# {'puuid': 'bjA0G8FcgYC2ZrsF1Eoj4VB7I1idKuBYHrw8GTITPKc7TUAt8zWPdfKOGLobHZkY2LU7S-gEGXJdzg',
#  'gameName': '타 잔',
#  'tagLine': 'KR1'}

# %%
puu_id = res['puuid']

# %%
url2 = f'https://asia.api.riotgames.com/riot/account/v1/accounts/by-puuid/{puu_id}?api_key={api_key}'

# %%
res2=requests.get(url2).json()

# %%
res2
# Out:
# {'puuid': 'bjA0G8FcgYC2ZrsF1Eoj4VB7I1idKuBYHrw8GTITPKc7TUAt8zWPdfKOGLobHZkY2LU7S-gEGXJdzg',
#  'gameName': '타 잔',
#  'tagLine': 'KR1'}

# %%
url3 = f'https://kr.api.riotgames.com/lol/champion-mastery/v4/champion-masteries/by-puuid/{puu_id}?api_key={api_key}'

# %%
res3 = requests.get(url3).json()

# %%
res3
# Out:
# [{'puuid': 'bjA0G8FcgYC2ZrsF1Eoj4VB7I1idKuBYHrw8GTITPKc7TUAt8zWPdfKOGLobHZkY2LU7S-gEGXJdzg',
#   'championId': 64,
#   'championLevel': 7,
#   'championPoints': 507982,
#   'lastPlayTime': 1712766924000,
#   'championPointsSinceLastLevel': 486382,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'kpv3IRy8WHCpCpNSROR7a_t6e5K_3D0fLWvDK2tLeldC0Uwz'},
#  {'puuid': 'bjA0G8FcgYC2ZrsF1Eoj4VB7I1idKuBYHrw8GTITPKc7TUAt8zWPdfKOGLobHZkY2LU7S-gEGXJdzg',
#   'championId': 104,
#   'championLevel': 6,
#   'championPoints': 275458,
#   'lastPlayTime': 1710958117000,
#   'championPointsSinceLastLevel': 253858,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 3,
#   'summonerId': 'kpv3IRy8WHCpCpNSROR7a_t6e5K_3D0fLWvDK2tLeldC0Uwz'},
#  {'puuid': 'bjA0G8FcgYC2ZrsF1Eoj4VB7I1idKuBYHrw8GTITPKc7TUAt8zWPdfKOGLobHZkY2LU7S-gEGXJdzg',
#   'championId': 76,
#   'championLevel': 7,
#   'championPoints': 200134,
# ...

# %%
url4 = f'https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key={api_key}'

# %%
res4 = requests.get(url4).json()

# %%
res4
# Out:
# {'tier': 'CHALLENGER',
#  'leagueId': '03746e6d-117c-33f2-a366-332950715348',
#  'queue': 'RANKED_SOLO_5x5',
#  'name': "Sona's Sentinels",
#  'entries': [{'summonerId': 'c0inizr2OnvbeISvDPIJAdfMYXs2KBzE1_TtkG5djahL_92Boj7sUATs5A',
#    'leaguePoints': 872,
#    'rank': 'I',
#    'wins': 280,
#    'losses': 221,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'gbxzC9WXwuYAdZYO3Edzm2lGwDcG-BvA38B36gTKWEPAqBE',
#    'leaguePoints': 923,
#    'rank': 'I',
#    'wins': 312,
#    'losses': 258,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '-TyRwIh-atMpwTBMj8y9IU04Z4D9kxSkXsD_jvh4pBcTnN32xy_dJn13ag',
#    'leaguePoints': 974,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 34,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
# ...

# %% [markdown]
# # 챌린저 api를 가지고 entries를 DATAFRAME으로 만드세요
#
# ### leaguepoint 순으로 내림차순(sort)
# ### hotStreak=True인 사람이 몇명인지 확인

# %%
import pandas as pd

# %%
list = [] # 굳이 리스트에 안 넣고 못 만드나?
for i in res4['entries']:
    list.append(i)
print(list)
# Out:
# [{'summonerId': 'c0inizr2OnvbeISvDPIJAdfMYXs2KBzE1_TtkG5djahL_92Boj7sUATs5A', 'leaguePoints': 872, 'rank': 'I', 'wins': 280, 'losses': 221, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'summonerId': 'gbxzC9WXwuYAdZYO3Edzm2lGwDcG-BvA38B36gTKWEPAqBE', 'leaguePoints': 923, 'rank': 'I', 'wins': 312, 'losses': 258, 'veteran': False, 'inactive': False, 'freshBlood': False, 'hotStreak': False}, {'summonerId': '-TyRwIh-atMpwTBMj8y9IU04Z4D9kxSkXsD_jvh4pBcTnN32xy_dJn13ag', 'leaguePoints': 974, 'rank': 'I', 'wins': 86, 'losses': 34, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': True}, {'summonerId': 'DcljsqWVzfHyvSGCbeED3_dmAYCYln7AKYpulRbiwVVlWgzzd8BgK49Zhw', 'leaguePoints': 939, 'rank': 'I', 'wins': 553, 'losses': 495, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'summonerId': '4pqvfrTI-OpIY_IsNdxl8d_x-RKt_WV_wfflP8YN3JQhvd9akBIig4a58A', 'leaguePoints': 1007, 'rank': 'I', 'wins': 126, 'losses': 73, 've
# ...

# %%
df_test = pd.DataFrame(list)

# %%
df_test
# Out:
#                                             summonerId  leaguePoints rank  \
# 0    c0inizr2OnvbeISvDPIJAdfMYXs2KBzE1_TtkG5djahL_9...           872    I
# 1      gbxzC9WXwuYAdZYO3Edzm2lGwDcG-BvA38B36gTKWEPAqBE           923    I
# 2    -TyRwIh-atMpwTBMj8y9IU04Z4D9kxSkXsD_jvh4pBcTnN...           974    I
# 3    DcljsqWVzfHyvSGCbeED3_dmAYCYln7AKYpulRbiwVVlWg...           939    I
# 4    4pqvfrTI-OpIY_IsNdxl8d_x-RKt_WV_wfflP8YN3JQhvd...          1007    I
# ..                                                 ...           ...  ...
# 295  HLFnG8XxuLYhY_f_Aq3iaH9rrBdHbq74rtKHK6mP7bUj-L...           862    I
# 296    0KnspiUN67aaqGEEclF7itMVIP0LGx8tyIapbkbyCvRSijc          1189    I
# 297  035evV2cqf4uPvQnWbICeBAt7GzMHfzu6LO-E7uRAMdEg8...           964    I
# 298  QrtqROt5YR_MzPMigAS3pNjaoN_Q2CcxuScWdu2kUSiqRJ...          1002    I
# 299    NHRxT0ASlN9KE8n2c8YksaaVeaKee7VFTjq1g9bx0Cs7aPA          1054    I
#
#      wins  losses  veteran  inactive  freshBlood  hotStreak
# ...

# %%
# 선생님 코드
df = pd.DataFrame(res4['entries']) # 이렇게 바로 데이터프레임 만들 수 있음

# %%
df.sort_values(by=['leaguePoints'], ascending=False)
# Out:
#                                             summonerId  leaguePoints rank  \
# 290    pDTJlGM8I1ZGowfFzZB8ALH5w4jTh8ec9D-vtVuAIveQjv0          1651    I
# 189  bZ49QN8ZTOdttQWsS3uEeu8OSBcyGsJ8MaH_ct-Xwn-U7i...          1512    I
# 48   MQb0TgmMyKXZCIWtBgoT0jcB-xx0Po-9yxVJi6nvjKRTCF...          1464    I
# 274    Kx18SncX4OnOIcnA0DCl5a26MMAvfKc3vuiqR0GoThv38DM          1462    I
# 146    rrnP98uk8PEMEfN1CuFJa7Y1vgHmN7Q1bqf6ZFHou5bQ-yA          1427    I
# ..                                                 ...           ...  ...
# 242  gUqi0awWFw9BWO7g89ikgfQnKUqu03Zk8euLM6P-giI38S...           843    I
# 78     oDh0j_l3kmt-5J101MWNEmdCJW4EgiwmU2AOXTEQaB7WBMU           833    I
# 191    bu7od4G4_YKhDS7tdAI09dM97qty1Y3j0j4FjNkNHByu0bs           830    I
# 272  ay3YIEs7W2gZbIhXbsFN-YwK_GSKAJ-mp06NcCVVBpvYbV...           824    I
# 232  LWJnLO8UrnEmDsWv8-f3ucXBXuYugv-rC9JvPSi02obsrv...           820    I
#
#      wins  losses  veteran  inactive  freshBlood  hotStreak
# ...

# %%
len(df[df.hotStreak==True])
# Out:
# 74

# %% [markdown]
# # 파이썬에서 타임스탬프 가져오는 거

# %%
import time
from datetime import datetime

# %%
a = int(time.time())

# %%
a
# Out:
# 1713246121

# %%
datetime.fromtimestamp(a)
# Out:
# datetime.datetime(2024, 4, 16, 14, 42, 1)
